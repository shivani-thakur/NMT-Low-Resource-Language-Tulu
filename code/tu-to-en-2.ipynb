# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/summer-school-test/en_dev.txt
# /kaggle/input/summer-school-test/tu_dev.txt
# /kaggle/input/summer-school-test/kn_dev.txt
# /kaggle/input/summer-school-train/tu_tr.txt
# /kaggle/input/summer-school-train/en_tr.txt
# /kaggle/input/summer-school-train/kn_tr.txt

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
#!git checkout v0.10.2
##!python -m pip install --user ./
# !pip install --editable .
# %cd ..
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35203, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 35203 (delta 66), reused 80 (delta 48), pack-reused 35083
# Receiving objects: 100% (35203/35203), 25.23 MiB | 30.64 MiB/s, done.
# Resolving deltas: 100% (25556/25556), done.
# /kaggle/working/fairseq
# Obtaining file:///kaggle/working/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.16.0)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.3 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.26.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2023.12.25)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (4.66.4)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (21.3)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (4.9.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (5.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2024.3.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fairseq==0.12.2) (3.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 7.5 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 6.5 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 14.8 MB/s eta 0:00:00
# Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9573 sha256=bbbf611c1682d6110a7047161fb4ff92ab3372836c9dda589b93e01a8ac9e768
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1n5h1zvm/wheels/67/69/06/aa788a7d879a7513f5f2e5c6d56825b6813783cb55ac5c7f8d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=67578754b3fc79eccb3594605bd23d1f73fa42146beb811195508d6bd352d6d2
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.10.0 sacrebleu-2.4.2
# /kaggle/working

# %%
# !nvidia-smi
# Out:
# Thu Jul  4 09:40:33 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0             28W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install git+https://github.com/vmujadia/tokenizer.git --upgrade
# Out:
# Collecting git+https://github.com/vmujadia/tokenizer.git
#   Cloning https://github.com/vmujadia/tokenizer.git to /tmp/pip-req-build-h7bryh5x
#   Running command git clone --filter=blob:none --quiet https://github.com/vmujadia/tokenizer.git /tmp/pip-req-build-h7bryh5x
#   Resolved https://github.com/vmujadia/tokenizer.git to commit 93cd09b81702108a51c08c9796fd1cc941a1b98b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (2024.2.2)
# Building wheels for collected packages: IL-Tokenizer
#   Building wheel for IL-Tokenizer (setup.py) ... done
#   Created wheel for IL-Tokenizer: filename=IL_Tokenizer-0.0.2-py3-none-any.whl size=7225 sha256=fb9543a4b08546f8438fbb8a7cc50911ce24fcee62226f50e50199cab855f7ed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_wi5b63h/wheels/9a/fb/5b/3d75bfde8561726121c09f0f0a83389c05312df8a513808c41
# Successfully built IL-Tokenizer
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: IL-Tokenizer
# Successfully installed IL-Tokenizer-0.0.2

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git
# Out:
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148459, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (366/366), done.
# remote: Total 148459 (delta 565), reused 797 (delta 517), pack-reused 147572
# Receiving objects: 100% (148459/148459), 129.99 MiB | 25.33 MiB/s, done.
# Resolving deltas: 100% (114591/114591), done.

# %%
# !git clone https://github.com/rsennrich/subword-nmt.git
# Out:
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 600 (delta 10), reused 12 (delta 4), pack-reused 576
# Receiving objects: 100% (600/600), 253.58 KiB | 8.18 MiB/s, done.
# Resolving deltas: 100% (359/359), done.

# %%
# !ls mosesdecoder/scripts/training/clean-corpus-n.perl
# Out:
# mosesdecoder/scripts/training/clean-corpus-n.perl

# %%
# Use the datasets already downloaded in the Kaggle notebook
# !cp /kaggle/input/summer-school-train/tu_tr.txt train.src
# !cp /kaggle/input/summer-school-train/en_tr.txt train.tgt
# !cp /kaggle/input/summer-school-test/tu_dev.txt valid.src
# !cp /kaggle/input/summer-school-test/en_dev.txt valid.tgt

# %%
print ('Data Stats')
! wc -l train.*
! wc -l valid.*
# Out:
# Data Stats
#    8300 train.src
#    8300 train.tgt
#   16600 total
#   1000 valid.src
#   1000 valid.tgt
#   2000 total

# %%
from ilstokenizer import tokenizer
import codecs

def to_tokenize_and_lower(input_path, output_path):
  outfile = open(output_path, 'w')
  for line in codecs.open(input_path):
    line = line.strip()
    line = tokenizer.tokenize(line).lower()
    #print (line)
    outfile.write(line+'\n')
  outfile.close()

# %%
to_tokenize_and_lower('train.src','train.src.tkn')
to_tokenize_and_lower('train.tgt','train.tgt.tkn')

to_tokenize_and_lower('valid.src','valid.src.tkn')
to_tokenize_and_lower('valid.tgt','valid.tgt.tkn')

# %%
! cat train.src.tkn > train.all.tkn
! cat train.tgt.tkn >> train.all.tkn

# %%
! perl mosesdecoder/scripts/training/clean-corpus-n.perl -ratio 5 train src.tkn tgt.tkn train_filtered 1 512
# Out:
# clean-corpus.perl: processing train.src.tkn & .tgt.tkn to train_filtered, cutoff 1-512, ratio 5
#
# Input sentences: 8300  Output sentences:  8290

# %%
print ('Data Stats')
! wc -l train*
! wc -l valid*
# Out:
# Data Stats
#   16600 train.all.tkn
#    8300 train.src
#    8300 train.src.tkn
#    8300 train.tgt
#    8300 train.tgt.tkn
#    8290 train_filtered.src.tkn
#    8290 train_filtered.tgt.tkn
#   66380 total
#   1000 valid.src
#   1000 valid.src.tkn
#   1000 valid.tgt
#   1000 valid.tgt.tkn
#   4000 total

# %%
# !python subword-nmt/subword_nmt/learn_bpe.py -s 3500 < train.all.tkn > train.codes
# Out:
# 100%|######################################| 3500/3500 [00:07<00:00, 456.97it/s]

# %%
! head -n 10 train.codes
# Out:
# #version: 0.2
# t h
# th e</w>
# i n
# ಲ ್
# a n
# ರ ್
# i s</w>
# ಂ ದ
# ತ ್

# %%
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.src.tkn > train.tu
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.tgt.tkn > train.en

# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes
# ಸುರೇಶೆ ತೂವೊಂದುಲ್ಲೆ
# ಪದಿನಾಜಿ ದಿನ@@ ರ್ದು ಬೊಕ ಬಾಲೆಗ್ ಎ@@ ಣ್ಣೆ ಪೂ@@ ಜು@@ ವೆರ್

# %%
import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"

! echo $PYTHONPATH
# Out:
# /kaggle/lib/kagglegym:/kaggle/lib:/content/fairseq/

# %%
! python fairseq/fairseq_cli/preprocess.py \
    --joined-dictionary \
    --source-lang tu --target-lang en \
    --trainpref train --validpref valid --testpref valid \
    --destdir data-bin/trial --thresholdtgt 0 --thresholdsrc 0 \
    --workers 20
# Out:
# 2024-07-04 09:43:55.729738: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 09:43:55.729898: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 09:43:55.851553: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /kaggle/working/fairseq/fairseq/tasks/multires_hubert_pretraining.py:154: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   dictionaries = [ (Dictionary.load(f"{label_dir}/dict.{label}.txt") if label is not "" else None ) for label in self.cfg.labels]
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
ls data-bin/trial
# Out:
# dict.en.txt        test.tu-en.en.idx   train.tu-en.en.idx  valid.tu-en.en.idx
# dict.tu.txt        test.tu-en.tu.bin   train.tu-en.tu.bin  valid.tu-en.tu.bin
# preprocess.log     test.tu-en.tu.idx   train.tu-en.tu.idx  valid.tu-en.tu.idx
# test.tu-en.en.bin  train.tu-en.en.bin  valid.tu-en.en.bin

# %%
! python fairseq/fairseq_cli/train.py --fp16 \
    data-bin/trial \
    --source-lang tu --target-lang en \
    --arch transformer_iwslt_de_en --share-all-embeddings \
    --encoder-embed-dim	512 --encoder-ffn-embed-dim	512 \
    --encoder-layers	8 --encoder-attention-heads	8 \
    --decoder-embed-dim	512 --decoder-ffn-embed-dim	512 \
    --decoder-layers	8 --decoder-attention-heads	8 \
    --dropout 0.3 --weight-decay 0.0 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 0.01 --lr-scheduler inverse_sqrt --warmup-updates 10 \
    --max-tokens 4096 --update-freq 16 \
    --max-update 1000 \
    --keep-last-epochs	10 \
    --save-dir trained_models
# Out:
# 2024-07-04 09:47:21.931434: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 09:47:21.931489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 09:47:21.933162: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# epoch 001:   0%|                                          | 0/4 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# epoch 001:  75%|█████████████████████████▌        | 3/4 [00:09<00:03,  3.15s/it]
# epoch 001 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.07it/s]
# epoch 001 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 15.50it/s]
# epoch 001 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.45it/s]
# epoch 002:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.41s/it]
# epoch 002 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.46it/s]
# epoch 002 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.20it/s]
# epoch 002 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.81it/s]
# epoch 003:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.38s/it]
# epoch 003 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.29it/s]
# epoch 003 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.42it/s]
# epoch 003 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.99it/s]
# epoch 004:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.41s/it]
# epoch 004 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.35it/s]
# epoch 004 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.04it/s]
# epoch 004 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.77it/s]
# epoch 005:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.42s/it]
# epoch 005 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.87it/s]
# epoch 005 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.35it/s]
# epoch 005 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.71it/s]
# epoch 006:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.35s/it]
# epoch 006 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 006 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.79it/s]
# epoch 006 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.46it/s]
# epoch 006 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.02it/s]
# epoch 007:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.38s/it]
# epoch 007 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 007 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 13.77it/s]
# epoch 007 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 15.64it/s]
# epoch 007 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.32it/s]
# epoch 008:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.35s/it]
# epoch 008 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch
| valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.69it/s]
# epoch 240 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.73it/s]
# epoch 240 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.08it/s]
# epoch 241:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.39s/it]
# epoch 241 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 241 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.41it/s]
# epoch 241 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.18it/s]
# epoch 241 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.82it/s]
# epoch 242:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.38s/it]
# epoch 242 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 242 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.34it/s]
# epoch 242 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.20it/s]
# epoch 242 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.87it/s]
# epoch 243:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.41s/it]
# epoch 243 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 243 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.41it/s]
# epoch 243 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.24it/s]
# epoch 243 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.87it/s]
# epoch 244:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.40s/it]
# epoch 244 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 244 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.70it/s]
# epoch 244 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.75it/s]
# epoch 244 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.18it/s]
# epoch 245:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.42s/it]
# epoch 245 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 245 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.28it/s]
# epoch 245 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.03it/s]
# epoch 245 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.55it/s]
# epoch 246:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.40s/it]
# epoch 246 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 246 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.82it/s]
# epoch 246 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.48it/s]
# epoch 246 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.01it/s]
# epoch 247:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.41s/it]
# epoch 247 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 247 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.98it/s]
# epoch 247 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.51it/s]
# epoch 247 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.05it/s]
# epoch 248:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.41s/it]
# epoch 248 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 248 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.90it/s]
# epoch 248 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.82it/s]
# epoch 248 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.18it/s]
# epoch 249:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.36s/it]
# epoch 249 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 249 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.87it/s]
# epoch 249 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.44it/s]
# epoch 249 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.00it/s]
# epoch 250:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.44s/it]
# epoch 250 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 250 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.19it/s]
# epoch 250 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 15.89it/s]
# epoch 250 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 16.51it/s]
# epoch 251:  75%|█████████████████████████▌        | 3/4 [00:07<00:02,  2.51s/it]
# epoch 251 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 251 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.63it/s]
# epoch 251 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.71it/s]
# epoch 251 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.16it/s]
# epoch 252:  25%|████████▌                         | 1/4 [00:02<00:07,  2.41s/it]
# epoch 252 | valid on 'valid' subset:   0%|                | 0/8 [00:00<?, ?it/s]
# epoch 252 | valid on 'valid' subset:  25%|██      | 2/8 [00:00<00:00, 14.76it/s]
# epoch 252 | valid on 'valid' subset:  50%|████    | 4/8 [00:00<00:00, 16.62it/s]
# epoch 252 | valid on 'valid' subset:  75%|██████  | 6/8 [00:00<00:00, 17.04it/s]

# %%
ls trained_models
# Out:
# checkpoint242.pt  checkpoint245.pt  checkpoint248.pt  checkpoint251.pt
# checkpoint243.pt  checkpoint246.pt  checkpoint249.pt  checkpoint_best.pt
# checkpoint244.pt  checkpoint247.pt  checkpoint250.pt  checkpoint_last.pt

# %%
! python fairseq/fairseq_cli/interactive.py data-bin/trial \
  -s tu -t en \
  --distributed-world-size 1 \
  --path trained_models/checkpoint_best.pt \
  --batch-size 64 --buffer-size 2500 --beam 10 \
  --skip-invalid-size-inputs-valid-test \
  --input valid.tu > valid.en.translated
# Out:
# 2024-07-04 10:36:22.156880: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 10:36:22.156945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 10:36:22.158960: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from sacrebleu import corpus_bleu

# Step 1: Read the translated output
translated_output_file = "valid.en.translated" 
translated_output = []
with open(translated_output_file, "r") as f:
    for line in f:
        translated_output.append(line.strip())

# Step 2: Read the reference translations
reference_file = "valid.en"  
reference_translations = []
with open(reference_file, "r") as f:
    for line in f:
        reference_translations.append(line.strip())

# Step 3: Tokenize the translated output and reference translations
tokenized_output = [tokenizer.tokenize(sentence).lower() for sentence in translated_output]
tokenized_references = [[tokenizer.tokenize(sentence).lower()] for sentence in reference_translations]

# Step 4: Compute the BLEU score
bleu_score = corpus_bleu(tokenized_output, tokenized_references)
print("BLEU score:", bleu_score.score)
# Out:
# BLEU score: 10.04916995660316
