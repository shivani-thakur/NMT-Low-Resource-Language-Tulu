# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/summer-school-train/tu_tr.txt
# /kaggle/input/summer-school-train/en_tr.txt
# /kaggle/input/summer-school-train/kn_tr.txt
# /kaggle/input/summer-school-test/en_dev.txt
# /kaggle/input/summer-school-test/tu_dev.txt
# /kaggle/input/summer-school-test/kn_dev.txt

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
#!git checkout v0.10.2
##!python -m pip install --user ./
# !pip install --editable .
# %cd ..
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35203, done.
# remote: Total 35203 (delta 0), reused 0 (delta 0), pack-reused 35203
# Receiving objects: 100% (35203/35203), 25.35 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (25494/25494), done.
# /kaggle/working/fairseq
# Obtaining file:///kaggle/working/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.16.0)
# Requirement already satisfied: cython in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (3.0.8)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.3 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.26.4)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2023.12.25)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (4.66.4)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (2.1.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (1.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fairseq==0.12.2) (21.3)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from omegaconf<2.1->fairseq==0.12.2) (4.9.0)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.10.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (5.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13->fairseq==0.12.2) (2024.3.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi->fairseq==0.12.2) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fairseq==0.12.2) (3.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->fairseq==0.12.2) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 8.6 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 8.2 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 19.1 MB/s eta 0:00:00
# Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9573 sha256=956c915e32c4455f80965544f823591ad7f68d866a678ec63b2ffdebcb2510d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-15kp5ddt/wheels/67/69/06/aa788a7d879a7513f5f2e5c6d56825b6813783cb55ac5c7f8d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=e615a05843573accdda12e26b9688df8e15620c43fb739b3cf6618f27d234449
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.2 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.10.0 sacrebleu-2.4.2
# /kaggle/working

# %%
# !nvidia-smi
# Out:
# Thu Jul  4 11:27:26 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             25W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install git+https://github.com/vmujadia/tokenizer.git --upgrade
# Out:
# Collecting git+https://github.com/vmujadia/tokenizer.git
#   Cloning https://github.com/vmujadia/tokenizer.git to /tmp/pip-req-build-seim3mbj
#   Running command git clone --filter=blob:none --quiet https://github.com/vmujadia/tokenizer.git /tmp/pip-req-build-seim3mbj
#   Resolved https://github.com/vmujadia/tokenizer.git to commit 93cd09b81702108a51c08c9796fd1cc941a1b98b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from IL-Tokenizer==0.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->IL-Tokenizer==0.0.2) (2024.2.2)
# Building wheels for collected packages: IL-Tokenizer
#   Building wheel for IL-Tokenizer (setup.py) ... done
#   Created wheel for IL-Tokenizer: filename=IL_Tokenizer-0.0.2-py3-none-any.whl size=7225 sha256=6ad1a0ac5e5ab4ba22441ba45e4edbd4d6499e17d39ec084eb35632da86d208a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p5so5pbh/wheels/9a/fb/5b/3d75bfde8561726121c09f0f0a83389c05312df8a513808c41
# Successfully built IL-Tokenizer
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: IL-Tokenizer
# Successfully installed IL-Tokenizer-0.0.2

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git
# Out:
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148459, done.
# remote: Counting objects: 100% (887/887), done.
# remote: Compressing objects: 100% (366/366), done.
# remote: Total 148459 (delta 565), reused 797 (delta 517), pack-reused 147572
# Receiving objects: 100% (148459/148459), 129.99 MiB | 14.54 MiB/s, done.
# Resolving deltas: 100% (114591/114591), done.

# %%
# !git clone https://github.com/rsennrich/subword-nmt.git
# Out:
# Cloning into 'subword-nmt'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 600 (delta 10), reused 12 (delta 4), pack-reused 576
# Receiving objects: 100% (600/600), 253.58 KiB | 19.51 MiB/s, done.
# Resolving deltas: 100% (359/359), done.

# %%
# !ls mosesdecoder/scripts/training/clean-corpus-n.perl
# Out:
# mosesdecoder/scripts/training/clean-corpus-n.perl

# %%
# Use the datasets already downloaded in the Kaggle notebook
# !cp /kaggle/input/summer-school-train/tu_tr.txt train.src
# !cp /kaggle/input/summer-school-train/en_tr.txt train.tgt
# !cp /kaggle/input/summer-school-test/tu_dev.txt valid.src
# !cp /kaggle/input/summer-school-test/en_dev.txt valid.tgt

# %%
print ('Data Stats')
! wc -l train.*
! wc -l valid.*
# Out:
# Data Stats
#    8300 train.src
#    8300 train.tgt
#   16600 total
#   1000 valid.src
#   1000 valid.tgt
#   2000 total

# %%
from ilstokenizer import tokenizer
import codecs

def to_tokenize_and_lower(input_path, output_path):
  outfile = open(output_path, 'w')
  for line in codecs.open(input_path):
    line = line.strip()
    line = tokenizer.tokenize(line).lower()
    #print (line)
    outfile.write(line+'\n')
  outfile.close()

# %%
to_tokenize_and_lower('train.src','train.src.tkn')
to_tokenize_and_lower('train.tgt','train.tgt.tkn')

to_tokenize_and_lower('valid.src','valid.src.tkn')
to_tokenize_and_lower('valid.tgt','valid.tgt.tkn')

# %%
! cat train.src.tkn > train.all.tkn
! cat train.tgt.tkn >> train.all.tkn

# %%
! perl mosesdecoder/scripts/training/clean-corpus-n.perl -ratio 2.5 train src.tkn tgt.tkn train_filtered 1 512
# Out:
# clean-corpus.perl: processing train.src.tkn & .tgt.tkn to train_filtered, cutoff 1-512, ratio 2.5
#
# Input sentences: 8300  Output sentences:  7951

# %%
print ('Data Stats')
! wc -l train*
! wc -l valid*
# Out:
# Data Stats
#   16600 train.all.tkn
#    8300 train.src
#    8300 train.src.tkn
#    8300 train.tgt
#    8300 train.tgt.tkn
#    7951 train_filtered.src.tkn
#    7951 train_filtered.tgt.tkn
#   65702 total
#   1000 valid.src
#   1000 valid.src.tkn
#   1000 valid.tgt
#   1000 valid.tgt.tkn
#   4000 total

# %%
# !python subword-nmt/subword_nmt/learn_bpe.py -s 1000 < train.all.tkn > train.codes
# Out:
# 100%|######################################| 1000/1000 [00:03<00:00, 332.89it/s]

# %%
! head -n 10 train.codes
# Out:
# #version: 0.2
# t h
# th e</w>
# i n
# ಲ ್
# a n
# ರ ್
# i s</w>
# ಂ ದ
# ತ ್

# %%
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.src.tkn > train.tu
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < train.tgt.tkn > train.en

# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < valid.src.tkn > valid.tu
# !python subword-nmt/subword_nmt/apply_bpe.py -c train.codes < valid.tgt.tkn > valid.en

# %%
! head -n 10 train.en
# Out:
# the ch@@ ang@@ e was writ@@ t@@ en by ch@@ and@@ u
# god giv@@ es every@@ thing when he giv@@ es it
# also , the p@@ ain of the min@@ d does not go a@@ way .
# the po@@ t@@ en@@ ti@@ al is on the mo@@ ve
# there was a s@@ ci@@ ence that we did not un@@ d@@ er@@ st@@ and e@@ as@@ ily .
# in the in@@ v@@ est@@ ig@@ ation of this c@@ as@@ e , as p@@ er the di@@ rec@@ tion of d@@ k district su@@ per@@ int@@ end@@ ent of p@@ ol@@ ice sh@@ ri h@@ ri@@ shi@@ k@@ esh s@@ on@@ a@@ wan@@ e i@@ ps , un@@ der the gu@@ id@@ ance of d@@ k district ad@@ d@@ it@@ i@@ on@@ al su@@ per@@ int@@ end@@ ent of p@@ ol@@ ice sh@@ ri v@@ .@@ b . bh@@ as@@ k@@ ar , ban@@ tw@@ al su@@ b - d@@ iv@@ is@@ i@@ on@@ al de@@ pu@@ ty su@@ per@@ int@@ end@@ ent of p@@ ol@@ ice sh@@ ri v@@ al@@ ent@@ in d ' s@@ ou@@ z@@ a , ban@@ tw@@ al c@@ ity p@@ ol@@ ice st@@ ation in@@ spe@@ c@@ t@@ or ch@@ el@@ u@@ v@@ ar@@ aj@@ u b . ban@@ tw@@ al c@@ ity p@@ ol@@ ice st@@ ation su@@ b - in@@ spe@@ c@@ t@@ or and st@@ af@@ f , ban@@ tw@@ al ru@@ ra@@ l p@@ ol@@ ice st@@ ation su@@ b - in@@ spe@@ c@@ t@@ or and st@@ af@@ f , ban@@ tw@@ al c@@ ity p@@ ol@@ ice st@@ ation c@@ ri@@ me br@@ an@@ ch p@@ ol@@ ice su@@ b - in@@ spe@@ c@@ t@@ or
# lo@@ st to time
# there has been a fi@@ er@@ ce t@@ us@@ s@@ le be@@ tw@@ e@@ en s@@ on@@ ow@@ al and in@@ fl@@ u@@ en@@ ti@@ al le@@ ad@@ er hi@@ man@@ ta b@@ is@@ w@@ a s@@ ar@@ ma for the ne@@ x@@ t ch@@ i@@ e@@ f min@@ i@@ ster of as@@ s@@ am .
# su@@ re@@ sh@@ an is wat@@ ching
# b@@ en@@ d and st@@ ra@@ i@@ gh@@ t@@ en the child ' s ar@@ m@@ s and le@@ g@@ s .

# %%
! head -n 10 train.tu
# Out:
# ಬ@@ ದ@@ ಲಾ@@ ವ@@ ಣೆ ಬರೆ@@ ಯಿ@@ ನಾ@@ ರ್ ಚ@@ ಂದು ಪನ್@@ ಪಿ@@ ನಾ@@ ರ್
# ದೇ@@ ವೆರ್ ಕೊರ್@@ ನಗ ಮಾ@@ ತ@@ ಲ ಕೊರ್@@ ಪೆರ್
# ಅಂಚ@@ ನೆ ಮ@@ ನ@@ ಸು@@ ಗು ಆ@@ ಯಿನ ಬೇ@@ ನೆ ಆ ಬೇ@@ ನೆ ಮಾ@@ ಜು@@ ಜಿ
# ವಿ@@ ಭ@@ ವೆ ನಡ@@ ತೊಂದುಲ್ಲೆ
# ನ@@ ಮ@@ ಕ್ ಸೊ@@ ಲ@@ ಬೊ@@ ಗು ಅರ್@@ ಥ ಆವ@@ ಂದ@@ ಿನ ಒಂಜಿ ವಿ@@ ಜ್@@ ಞ@@ ಾ@@ ನ ಇ@@ ತ್ತ್@@ ಂಡ್
# ಈ ಪ್ರ@@ ಕರ@@ ಣ@@ ದ ಪ@@ ತ್ತ@@ ೆಡ್ ದ@@ .@@ ಕ ಜಿಲ್ಲ@@ ಾ ಪೊ@@ ಲೀ@@ ಸ್ ಅ@@ ಧ@@ ೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ@@ ಾ@@ ಯಿನ ಶ್@@ ರ@@ ೀ ಋ@@ ಷ@@ ಿ@@ ಕೇ@@ ಶ@@ ್ ಸೋ@@ ನಾ@@ ವ@@ ಣೆ ಐ@@ .@@ ಪಿ@@ .@@ ಎ@@ ಸ್ ಮೆ@@ ರ್ನ ನಿ@@ ರ್@@ ದೇ@@ ಶ@@ ನ@@ ದ ಪ್ರ@@ ಕಾರ ದ@@ .@@ ಕ ಜಿಲ್ಲ@@ ಾ ಹ@@ ೆ@@ ಚ್ಚ@@ ು@@ ವ@@ ರಿ ಪೊ@@ ಲೀ@@ ಸ್ ಅ@@ ಧ@@ ೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ@@ ಾ@@ ಯಿನ ಶ್@@ ರ@@ ೀ ವಿ@@ .@@ ಬ@@ ಿ ಭಾ@@ ಸ್@@ ಕ@@ ರ್ ಮೆ@@ ರ್ನ ಮಾ@@ ರ್@@ ಗ@@ ದರ್@@ ಶ@@ ನ@@ ಡ್ ಬಂ@@ ಟ್@@ ವಾ@@ ಳ ಉ@@ ಪ@@ ವಿ@@ ಭಾ@@ ಗ@@ ದ ಪೊ@@ ಲೀ@@ ಸ್ ಉ@@ ಪಾ@@ ಧ@@ ೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ@@ ಾ@@ ಯಿನ ಶ್@@ ರ@@ ೀ ವೆ@@ ಲ@@ ೈ@@ ಂಟ@@ ೈ@@ ನ್ ಡಿ@@ ಸೋ@@ ಜ@@ ಾ ಮೆ@@ ರ್ನ ಮು@@ ತಾ@@ ಲಿ@@ ಕೆ@@ ಡ್ ಬಂ@@ ಟ್@@ ವಾ@@ ಳ ನ@@ ಗ@@ ರ ಠ@@ ಾ@@ ಣ@@ ಾ ಪೊ@@ ಲೀ@@ ಸ್ ನಿ@@ ರೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ@@ ಾ@@ ಯಿನ ಚ@@ ೆ@@ ಲು@@ ವ@@ ರಾ@@ ಜ@@ ು ಬ@@ ಿ , ಬಂ@@ ಟ್@@ ವಾ@@ ಳ ನ@@ ಗ@@ ರ ಠ@@ ಾ@@ ಣ@@ ಾ ಪೊ@@ ಲೀ@@ ಸ್ ಉ@@ ಪ@@ ನಿ@@ ರೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ್ ಬೊಕ್ಕ ಸಿ@@ ಬ್ಬ@@ ಂದಿ@@ ಲು ಬಂ@@ ಟ್@@ ವಾ@@ ಳ ಗ್@@ ರಾ@@ ಮಾ@@ ಂ@@ ತ@@ ರ ಪೊ@@ ಲೀ@@ ಸ್ ಠ@@ ಾ@@ ಣ@@ ಾ ಉ@@ ಪ@@ ನಿ@@ ರೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ್ ಅಂಚ@@ ನೇ ಸಿ@@ ಬ್ಬ@@ ಂದಿ@@ ನ@@ ಕುಲು ಬಂ@@ ಟ್@@ ವಾ@@ ಳ ನ@@ ಗ@@ ರ ಪೊ@@ ಲೀ@@ ಸ್ ಠ@@ ಾ@@ ಣ@@ ಾ ಅ@@ ಪ@@ ರಾ@@ ಧ ವಿ@@ ಭಾ@@ ಗ@@ ದ ಪೊ@@ ಲೀ@@ ಸ್ ಉ@@ ಪ@@ ನಿ@@ ರೀ@@ ಕ್ಷ@@ ಕ@@ ೆರ@@ ಾ@@ ಯಿನ ,
# ತ@@ ತ್ತ@@ ಿ ಕಾಲ@@ ೊ@@ ಗು ಸೋ@@ ಲು
# ಅ@@ ಸ್@@ ಸಾ@@ ಂ ದ ದು@@ ಂಬು@@ ದ ಮು@@ ಖ@@ ್ಯ@@ ಮ@@ ಂತ್@@ ರಿ ಸ್ಥ@@ ಾ@@ ನ@@ ಗಾ@@ ದ್ ಸೋ@@ ನೊ@@ ವಾ@@ ಲ್ ಬೊಕ್ಕ ಪ್ರ@@ ಭಾ@@ ವ@@ ಿ ನಾಯ@@ ಕ ಹಿ@@ ಮ@@ ಂ@@ ತ ಬಿ@@ ಸ್@@ ವ@@ ಾ ಶ@@ ರ್ಮ@@ ಾ ನ@@ ಡು@@ ಟು ತೀ@@ ವ್@@ ರ ಪ@@ ೈ@@ ಪೋ@@ ಟ@@ ಿ ಆ@@ ತುಂಡು .
# ಸು@@ ರ@@ ೇಶೆ ತೂ@@ ವೊಂದುಲ್ಲೆ
# ಪ@@ ದಿ@@ ನಾ@@ ಜಿ ದಿನ@@ ರ್@@ ದು ಬೊ@@ ಕ ಬಾ@@ ಲೆಗ್ ಎ@@ ಣ್@@ ಣೆ ಪೂ@@ ಜು@@ ವೆರ್

# %%
import os
os.environ['PYTHONPATH'] += ":/content/fairseq/"

! echo $PYTHONPATH
# Out:
# /kaggle/lib/kagglegym:/kaggle/lib:/content/fairseq/

# %%
! python fairseq/fairseq_cli/preprocess.py \
    --joined-dictionary \
    --source-lang tu --target-lang en \
    --trainpref train --validpref valid --testpref valid \
    --destdir data-bin/trial --thresholdtgt 0 --thresholdsrc 0 \
    --workers 20
# Out:
# 2024-07-04 11:29:29.545757: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 11:29:29.545857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 11:29:29.740051: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /kaggle/working/fairseq/fairseq/tasks/multires_hubert_pretraining.py:154: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   dictionaries = [ (Dictionary.load(f"{label_dir}/dict.{label}.txt") if label is not "" else None ) for label in self.cfg.labels]
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
ls data-bin/trial
# Out:
# dict.en.txt        test.tu-en.en.idx   train.tu-en.en.idx  valid.tu-en.en.idx
# dict.tu.txt        test.tu-en.tu.bin   train.tu-en.tu.bin  valid.tu-en.tu.bin
# preprocess.log     test.tu-en.tu.idx   train.tu-en.tu.idx  valid.tu-en.tu.idx
# test.tu-en.en.bin  train.tu-en.en.bin  valid.tu-en.en.bin

# %%
! python fairseq/fairseq_cli/train.py --fp16 \
    data-bin/trial \
    --source-lang tu --target-lang en \
    --arch transformer_iwslt_de_en --share-all-embeddings \
    --encoder-embed-dim	2048 --encoder-ffn-embed-dim	2048 \
    --encoder-layers	8 --encoder-attention-heads	16 \
    --decoder-embed-dim	2048 --decoder-ffn-embed-dim	2048 \
    --decoder-layers	8 --decoder-attention-heads	16 \
    --dropout 0.3 --weight-decay 0.0 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 0.01 --lr-scheduler inverse_sqrt --warmup-updates 10 \
    --max-tokens 4096 --update-freq 16 \
    --max-update 1000 \
    --keep-last-epochs	10 \
    --save-dir trained_models
# Out:
# 2024-07-04 11:31:57.344099: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 11:31:57.344179: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-04 11:31:57.345812: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# epoch 001:   0%|                                          | 0/5 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# epoch 001:  80%|███████████████████████████▏      | 4/5 [01:42<00:25, 25.45s/it]
# epoch 001 | valid on 'valid' subset:   0%|                | 0/9 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  11%|▉       | 1/9 [00:00<00:04,  1.90it/s]
# epoch 001 | valid on 'valid' subset:  22%|█▊      | 2/9 [00:00<00:03,  2.04it/s]
# epoch 001 | valid on 'valid' subset:  33%|██▋     | 3/9 [00:01<00:02,  2.04it/s]
# epoch 001 | valid on 'valid' subset:  44%|███▌    | 4/9 [00:02<00:02,  1.98it/s]
# epoch 001 | valid on 'valid' subset:  56%|████▍   | 5/9 [00:02<00:02,  1.90it/s]
# epoch 001 | valid on 'valid' subset:  67%|█████▎  | 6/9 [00:03<00:01,  1.92it/s]
# epoch 001 | valid on 'valid' subset:  78%|██████▏ | 7/9 [00:03<00:01,  1.88it/s]
# epoch 001 | valid on 'valid' subset:  89%|███████ | 8/9 [00:04<00:00,  1.83it/s]
# epoch 001 | valid on 'valid' subset: 100%|████████| 9/9 [00:04<00:00,  1.75it/s]
# epoch 002:  80%|███████████████████████████▏      | 4/5 [01:34<00:23, 23.55s/it]
# epoch 002 | valid on 'valid' subset:   0%|                | 0/9 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  11%|▉       | 1/9 [00:00<00:04,  1.91it/s]
# epoch 002 | valid on 'valid' subset:  22%|█▊      | 2/9 [00:00<00:03,  2.04it/s]
# epoch 002 | valid on 'valid' subset:  33%|██▋     | 3/9 [00:01<00:02,  2.03it/s]
# epoch 002 | valid on 'valid' subset:  44%|███▌    | 4/9 [00:02<00:02,  1.98it/s]
# epoch 002 | valid on 'valid' subset:  56%|████▍   | 5/9 [00:02<00:02,  1.90it/s]
# epoch 002 | valid on 'valid' subset:  67%|█████▎  | 6/9 [00:03<00:01,  1.92it/s]
# epoch 002 | valid on 'valid' subset:  78%|██████▏ | 7/9 [00:03<00:01,  1.87it/s]
# epoch 002 | valid on 'valid' subset:  89%|███████ | 8/9 [00:04<00:00,  1.83it/s]
# epoch 002 | valid on 'valid' subset: 100%|████████| 9/9 [00:04<00:00,  1.75it/s]
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 619, in save
#     _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 833, in _save
#     zip_file.write_record('data.pkl', data_value, len(data_value))
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/kaggle/working/fairseq/fairseq/checkpoint_utils.py", line 586, in torch_persistent_save
#     _torch_persistent_save(obj, f)
#   File "/kaggle/working/fairseq/fairseq/checkpoint_utils.py", line 601, in _torch_persistent_save
#     return torch.save(obj, f)
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 618, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#   File "/opt/conda/lib/python3.10/site-packages/torch/serialization.py", line 482, in __exit__
#     self.file_like.write_end_of_file()
# RuntimeError: [enforce fail at inline_container.cc:424] . unexpected pos 64 vs 0
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/kaggle/working/fairseq/fairseq_cli/train.py", line 581, in <module>
#     cli_main()
#   File "/kaggle/working/fairseq/fairseq_cli/train.py", line 574, in cli_main
#     distributed_utils.call_main(cfg, main)
#   File "/kaggle/working/fairseq/fairseq/distributed/utils.py", line 404, in call_main
#     main(cfg, **kwargs)
#   File "/kaggle/working/fairseq/fairseq_cli/train.py", line 205, in main
#     valid_losses, should_stop = train(cfg, trainer, task, epoch_itr)
#   File "/opt/conda/lib/python3.10/contextlib.py", line 79, in inner
#     return func(*args, **kwds)
#   File "/kaggle/working/fairseq/fairseq_cli/train.py", line 345, in train
#     valid_losses, should_stop = validate_and_save(
#   File "/kaggle/working/fairseq/fairseq_cli/train.py", line 442, in validate_and_save
#     cp_path = checkpoint_utils.save_checkpoint(
#   File "/kaggle/working/fairseq/fairseq/checkpoint_utils.py", line 129, in save_checkpoint
#     saved_cp = trainer.save_checkpoint(checkpoints[0], extra_state)
#   File "/kaggle/working/fairseq/fairseq/trainer.py", line 456, in save_checkpoint
#     checkpoint_utils.torch_persistent_save(
#   File "/kaggle/working/fairseq/fairseq/checkpoint_utils.py", line 585, in torch_persistent_save
#     with PathManager.open(filename + ".tmp", "wb") as f:
# OSError: [Errno 28] No space left on device
